# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../raw_data/Japan_CPI.csv')

# %%
df.head()
# Out:
#          DATE  CPALTT01JPQ657N
# 0  1960-01-01         1.022844
# 1  1960-04-01         0.911239
# 2  1960-07-01         0.735786
# 3  1960-10-01         0.630810
# 4  1961-01-01         1.715605

# %%
sns.lineplot(df['CPALTT01JPQ657N'])
# Out:
# <Axes: ylabel='CPALTT01JPQ657N'>
